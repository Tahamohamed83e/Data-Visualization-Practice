# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic-Dataset.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(10,10))
plt.hist(df['Age'], bins=20 )
plt.title('Distribuation')
plt.xlabel('Age')
plt.ylabel('count')
plt.show()

# %%
sns.histplot(df['Age'] , bins=40 , kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
age_class = df.groupby('Pclass')['Age'].mean()
plt.plot(age_class.index, age_class.values)

# %%
#plt.plot(df['Pclass'],df['Age'])

# %%
sns.lineplot(data=df, x='Pclass' , y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
age_class = df.groupby('Pclass')['Age'].sum()
age_class
# Out:
# Pclass
# 1    7111.42
# 2    5168.83
# 3    8924.92
# Name: Age, dtype: float64

# %%
sns.scatterplot(data=df , x='Age' , y='Pclass' ,hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Pclass'>

# %%
sns.countplot(data=df , x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
count_ =df['Pclass'].value_counts()

# %%
plt.bar(count_.index,count_.values)
plt.xlabel('Pclass')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.scatter(df['Age'],df['Fare'])

# %%
sns.boxplot(data=df , x='Pclass', y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
plt.pie('Pclass', labels='Sex')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 plt.pie(y='Pclass', labels='Sex')
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: pie() got an unexpected keyword argument 'y'
